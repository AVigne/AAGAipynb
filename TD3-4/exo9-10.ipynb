# %% [markdown]
# # Exercice 9
#
# ### Question 9.1
#
# On commence par générer un arbre de Catalan uniforme, puis on étiquette les noeuds correctement afin d'obtenir un ABR.
#
# ### Question 9.2
#
# Selon wikipedia (https://en.wikipedia.org/wiki/Random_binary_tree) la profondeur moyenne d'une feuille dans les arbres de Catalan uniformes est √n. On pourrait le montrer sur des exemples en ajoutant une informations sur la profondeur d'un noeud dans la structure de l'exercice 2 et en générant de nombreux arbres de tailles différentes.
#
# ### Question 9.3
#
# Dans un ABR, la profondeur moyenne d'une feuille est log(n). En revanche, après de nombreuses modifications d'un tel arbre (insertions/suppressions) cette profondeur s'approche de √n (source : https://en.wikipedia.org/wiki/Binary_search_tree).
#
# # Exercice 10
#
# ### Question 10.1
#
# On choisit un contre-exemple simple : il existe 6 suites de 3 entiers ayant chacune une probabilité de 1/6 en distribution uniforme. Cependant, ces 6 suites n'induisent que 5 ABR car ceux induits par (2,1,3) et (2,3,1) sont les même.
#
# ### Question 10.2
#
# (1,2,3) :
# 1
# &nbsp; \
# &nbsp; 2
# &nbsp;&nbsp;  \
# &nbsp;&nbsp;  3
#
# (1,3,2) :
# 1
# &nbsp; \
# &nbsp;&nbsp; 3
# &nbsp;&nbsp;/
# &nbsp;2
#
# (2,1,3) et (2,3,1) :
# &nbsp;&nbsp;2
# &nbsp;/ \
# 1 3
#
# (3,1,2) :
# &nbsp;&nbsp;&nbsp;3
# &nbsp;&nbsp;/
# &nbsp;1
# &nbsp;&nbsp;\
# &nbsp;&nbsp;2
#
# (3,2,1) :
# &nbsp;&nbsp;&nbsp;3
# &nbsp;&nbsp;/
# &nbsp;&nbsp;2
# &nbsp;/
# 1
#
# ### Question 10.3
#
# En moyenne sur les 5 ABR de la question précédente, la profondeur d'une feuille est 5/3 (4 feuilles de profondeur 2 et 2 de profondeur 1).
#
# ### Question 10.4
#
# En moyenne, sur les 6 suites de 3 entiers, la profondeur d'une feuille est 1.5 (4 feuilles de profondeur 2 et 4 de profondeur 1).
#
# ### Question 10.5
#
# Dans un ABR, la profondeur moyenne d'une feuille représente le temps moyen de recherche d'un élément dans l'arbre.
# (à vérifier je suis pas sur du tout).
